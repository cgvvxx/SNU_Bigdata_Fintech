# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action='ignore')

pd.options.display.max_rows = 50
pd.options.display.max_columns = 100

train_df = pd.read_csv('pure_.csv')
train_edit_df = pd.read_csv('pure_가공.csv')

variables1 = train_df.drop('voted', axis=1)
predictor1 = train_df['voted']

variables2 = train_edit_df.drop('voted', axis=1)
predictor2 = train_edit_df['voted']
    
x_train1, x_test1, y_train1, y_test1 = train_test_split(variables1, predictor1)
x_train2, x_test2, y_train2, y_test2 = train_test_split(variables2, predictor2)

# %%
import numpy as np
from sklearn.decomposition import PCA

def pca_function(data, p):
    X_cen = data - data.mean(axis=0)
    X_cov = np.dot(X_cen.T, X_cen) / 59
    w, v = np.linalg.eig(X_cov)
    explained_variance_ratio= w / w.sum()
    cumsum = np.cumsum(explained_variance_ratio)
    d = np.argmax(cumsum >= p) + 1
    
    pca = PCA(n_components=d)
    data_pca = pca.fit(data)
    print('x_pca_train:',data_pca)

pca_function(variables1, 0.90)
pca_function(variables1, 0.95)
pca_function(variables1, 0.99)
pca_function(variables2, 0.90)
pca_function(variables2, 0.95)
pca_function(variables2, 0.99)
# Out:
# x_pca_train: PCA(n_components=3)
# x_pca_train: PCA(n_components=5)
# x_pca_train: PCA(n_components=8)
# x_pca_train: PCA(n_components=4)
# x_pca_train: PCA(n_components=5)
# x_pca_train: PCA(n_components=9)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, roc_auc_score
import statsmodels.api as sm

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline, make_pipeline

# %%
def star_print(word):
    
    print('                              ****************************************************************')
    print('                              **************** {0:^30} ****************'.format(word))
    print('                              ****************************************************************')
    print(' ')

def scores(model, scaler, y_test, y_pred, pca_print, edit_print):
    
    if edit_print == 0:
        edit = 'Raw Data       '
    else:
        edit = 'Processed Data '
        
    model_name = str(model)[:str(model).find('(')]
    
    if pca_print == 4:
        pca_num = 90
    elif pca_print == 5:
        pca_num = 95
    else:
        pca_num = 99
    pca_percent = ' & PCA(' + str(pca_num) + '%)'
    
    if pca_print == 0:
        print(edit + '[ {0:<55}] f1 score : {1:0.04f}, acc : {2:0.04f}, auc_score : {3:0.4f}'
          .format(model_name + ' / ' + str(scaler)[:-2], f1_score(y_test, y_pred)
                  , accuracy_score(y_test, y_pred), roc_auc_score(y_test, y_pred)))
    else:
        print(edit + '[ {0:<55}] f1 score : {1:0.04f}, acc : {2:0.04f}, auc_score : {3:0.4f}'
          .format(model_name + ' / ' + str(scaler)[:-2] + pca_percent, f1_score(y_test, y_pred)
                  , accuracy_score(y_test, y_pred), roc_auc_score(y_test, y_pred)))
        
    return f1_score(y_test, y_pred), accuracy_score(y_test, y_pred), roc_auc_score(y_test, y_pred)
    
    
def run_model(model):
    
    scalers_list = ['NoScaler()', StandardScaler(), RobustScaler(), MinMaxScaler()]
    acc_max = []
    
    star_print(str(model)[:str(model).find('(')])
    
    for scaler in scalers_list:
        for pca_check in [0, 4, 5, 9]:
            for edit_check in range(2):
                
                in_model = model
                    
                if pca_check == 0:
                    if scaler == 'NoScaler()':
                        pipeline = make_pipeline(in_model)
                    else:
                        pipeline = make_pipeline(scaler, in_model)
                else:
                    if scaler == 'NoScaler()':
                        pipeline = make_pipeline(PCA(n_components=pca_check), in_model)
                    else:
                        pipeline = make_pipeline(scaler, PCA(n_components=pca_check), in_model)
                        
                if edit_check == 0:
                    x_train, y_train, x_test, y_test = x_train1, y_train1, x_test1, y_test1
                else:
                    x_train, y_train, x_test, y_test = x_train2, y_train2, x_test2, y_test2
                
                pipeline.fit(x_train, y_train)
                y_pred = pipeline.predict(x_test)
                                
                if str(model)[:3] == 'Rid' or str(model)[:3] == 'Las' or str(model)[:3] == 'Ela' or str(model)[:3] == 'Lin':
                    y_pred = [1 if i > 0.5 else 0 for i in y_pred]

                f1, acc, auc = scores(model, scaler, y_test, y_pred, pca_check, edit_check)
                
                if len(acc_max) == 0 or acc_max[0] <= acc:
                    acc_max = []
                    acc_max.append(acc)
                    acc_max.append(f1)
                    acc_max.append(auc)
                    acc_max.append(model)
                    acc_max.append(scaler)
                    acc_max.append(pca_check)
                    acc_max.append(edit_check)
    
    print(' ')
    print(' ')
    
    return acc_max


def print_max_list(max_list):
    
    star_print('S U M M A R Y')
    
    for i in max_list:
        
        if i[5] == 0:
            pca_percent = 'PCA( X )'
        else:
            if i[5] == 4:
                pca_num = 90
            elif i[5] == 5:
                pca_num = 95
            else:
                pca_num = 99        
            pca_percent = 'PCA(' + str(pca_num) + '%)'
        
        if i[6] == 0:
            is_edit = 'Raw Data'
        else:
            is_edit = 'Processed Data'
            
        print('[ {0:<28} / {1:<14} / {2:<14} / {3} ] f1 score : {4:0.04f}, acc : {5:0.04f}, auc_score : {6:0.4f}'.format(
            str(i[3])[:str(i[3]).find('(')], str(i[4])[:-2], is_edit, pca_percent, i[1], i[0], i[2]))

# %%
models_list = [LinearRegression(), Ridge(), Lasso(), ElasticNet()
               , LogisticRegression(), GaussianNB(), LinearDiscriminantAnalysis(), LinearSVC()
               , DecisionTreeClassifier(), KNeighborsClassifier(), RandomForestClassifier()
               , AdaBoostClassifier(), GradientBoostingClassifier(), BaggingClassifier()
               , LGBMClassifier(), XGBClassifier(verbosity=0)]

max_list = []

for model in models_list:
    max_list.append(run_model(model))
    
print_max_list(max_list)
# Out:
#                               ****************************************************************
#                               ****************        LinearRegression        ****************
#                               ****************************************************************
#
# Raw Data       [ LinearRegression / NoScaler                            ] f1 score : 0.6248, acc : 0.6727, auc_score : 0.6666
# Processed Data [ LinearRegression / NoScaler                            ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# Raw Data       [ LinearRegression / NoScaler & PCA(90%)                 ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ LinearRegression / NoScaler & PCA(90%)                 ] f1 score : 0.5557, acc : 0.6441, auc_score : 0.6319
# Raw Data       [ LinearRegression / NoScaler & PCA(95%)                 ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearRegression / NoScaler & PCA(95%)                 ] f1 score : 0.5539, acc : 0.6436, auc_score : 0.6312
# Raw Data       [ LinearRegression / NoScaler & PCA(99%)                 ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearRegression / NoScaler & PCA(99%)                 ] f1 score : 0.6098, acc : 0.6598, auc_score : 0.6536
# Raw Data       [ LinearRegression / StandardScaler                      ] f1 score : 0.6245, acc : 0.6724, auc_score : 0.6663
# Processed Data [ LinearRegression / StandardScaler                      ] f1 score : 0.6279, acc : 0.6760, auc_score : 0.6699
# Raw Data       [ LinearRegression / StandardScaler & PCA(90%)           ] f1 score : 0.5712, acc : 0.6488, auc_score : 0.6371
# Processed Data [ LinearRegression / StandardScaler & PCA(90%)           ] f1 score : 0.5651, acc : 0.6521, auc_score : 0.6399
# Raw Data       [ LinearRegression / StandardScaler & PCA(95%)           ] f1 score : 0.5728, acc : 0.6506, auc_score : 0.6388
# Processed Data [ LinearRegression / StandardScaler & PCA(95%)           ] f1 score : 0.5680, acc : 0.6535, auc_score : 0.6414
# Raw Data       [ LinearRegression / StandardScaler & PCA(99%)           ] f1 score : 0.5676, acc : 0.6498, auc_score : 0.6372
# Processed Data [ LinearRegression / StandardScaler & PCA(99%)           ] f1 score : 0.5731, acc : 0.6555, auc_score : 0.6439
# Raw Data       [ LinearRegression / RobustScaler                        ] f1 score : 0.6248, acc : 0.6727, auc_score : 0.6666
# Processed Data [ LinearRegression / RobustScaler                        ] f1 score : 0.6241, acc : 0.6744, auc_score : 0.6679
# Raw Data       [ LinearRegression / RobustScaler & PCA(90%)             ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ LinearRegression / RobustScaler & PCA(90%)             ] f1 score : 0.6075, acc : 0.6602, auc_score : 0.6535
# Raw Data       [ LinearRegression / RobustScaler & PCA(95%)             ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearRegression / RobustScaler & PCA(95%)             ] f1 score : 0.6070, acc : 0.6597, auc_score : 0.6530
# Raw Data       [ LinearRegression / RobustScaler & PCA(99%)             ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearRegression / RobustScaler & PCA(99%)             ] f1 score : 0.6078, acc : 0.6634, auc_score : 0.6562
# Raw Data       [ LinearRegression / MinMaxScaler                        ] f1 score : 0.6257, acc : 0.6734, auc_score : 0.6673
# Processed Data [ LinearRegression / MinMaxScaler                        ] f1 score : 0.6252, acc : 0.6748, auc_score : 0.6684
# Raw Data       [ LinearRegression / MinMaxScaler & PCA(90%)             ] f1 score : 0.5562, acc : 0.6381, auc_score : 0.6260
# Processed Data [ LinearRegression / MinMaxScaler & PCA(90%)             ] f1 score : 0.5182, acc : 0.6349, auc_score : 0.6190
# Raw Data       [ LinearRegression / MinMaxScaler & PCA(95%)             ] f1 score : 0.5419, acc : 0.6410, auc_score : 0.6257
# Processed Data [ LinearRegression / MinMaxScaler & PCA(95%)             ] f1 score : 0.5173, acc : 0.6346, auc_score : 0.6186
# Raw Data       [ LinearRegression / MinMaxScaler & PCA(99%)             ] f1 score : 0.5424, acc : 0.6396, auc_score : 0.6247
# Processed Data [ LinearRegression / MinMaxScaler & PCA(99%)             ] f1 score : 0.5202, acc : 0.6356, auc_score : 0.6198
#
#
#                               ****************************************************************
#                               ****************             Ridge              ****************
#                               ****************************************************************
#
# Raw Data       [ Ridge / NoScaler                                       ] f1 score : 0.6248, acc : 0.6726, auc_score : 0.6665
# Processed Data [ Ridge / NoScaler                                       ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# Raw Data       [ Ridge / NoScaler & PCA(90%)                            ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Ridge / NoScaler & PCA(90%)                            ] f1 score : 0.5557, acc : 0.6441, auc_score : 0.6319
# Raw Data       [ Ridge / NoScaler & PCA(95%)                            ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Ridge / NoScaler & PCA(95%)                            ] f1 score : 0.5539, acc : 0.6436, auc_score : 0.6312
# Raw Data       [ Ridge / NoScaler & PCA(99%)                            ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Ridge / NoScaler & PCA(99%)                            ] f1 score : 0.6098, acc : 0.6598, auc_score : 0.6536
# Raw Data       [ Ridge / StandardScaler                                 ] f1 score : 0.6248, acc : 0.6727, auc_score : 0.6666
# Processed Data [ Ridge / StandardScaler                                 ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# Raw Data       [ Ridge / StandardScaler & PCA(90%)                      ] f1 score : 0.5713, acc : 0.6489, auc_score : 0.6372
# Processed Data [ Ridge / StandardScaler & PCA(90%)                      ] f1 score : 0.5598, acc : 0.6490, auc_score : 0.6365
# Raw Data       [ Ridge / StandardScaler & PCA(95%)                      ] f1 score : 0.5723, acc : 0.6503, auc_score : 0.6385
# Processed Data [ Ridge / StandardScaler & PCA(95%)                      ] f1 score : 0.5698, acc : 0.6537, auc_score : 0.6419
# Raw Data       [ Ridge / StandardScaler & PCA(99%)                      ] f1 score : 0.5670, acc : 0.6494, auc_score : 0.6368
# Processed Data [ Ridge / StandardScaler & PCA(99%)                      ] f1 score : 0.5730, acc : 0.6562, auc_score : 0.6444
# Raw Data       [ Ridge / RobustScaler                                   ] f1 score : 0.6249, acc : 0.6727, auc_score : 0.6666
# Processed Data [ Ridge / RobustScaler                                   ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# Raw Data       [ Ridge / RobustScaler & PCA(90%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Ridge / RobustScaler & PCA(90%)                        ] f1 score : 0.6073, acc : 0.6601, auc_score : 0.6534
# Raw Data       [ Ridge / RobustScaler & PCA(95%)                        ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Ridge / RobustScaler & PCA(95%)                        ] f1 score : 0.6071, acc : 0.6598, auc_score : 0.6531
# Raw Data       [ Ridge / RobustScaler & PCA(99%)                        ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Ridge / RobustScaler & PCA(99%)                        ] f1 score : 0.6078, acc : 0.6634, auc_score : 0.6562
# Raw Data       [ Ridge / MinMaxScaler                                   ] f1 score : 0.6248, acc : 0.6726, auc_score : 0.6665
# Processed Data [ Ridge / MinMaxScaler                                   ] f1 score : 0.6258, acc : 0.6744, auc_score : 0.6682
# Raw Data       [ Ridge / MinMaxScaler & PCA(90%)                        ] f1 score : 0.5562, acc : 0.6381, auc_score : 0.6260
# Processed Data [ Ridge / MinMaxScaler & PCA(90%)                        ] f1 score : 0.5182, acc : 0.6349, auc_score : 0.6190
# Raw Data       [ Ridge / MinMaxScaler & PCA(95%)                        ] f1 score : 0.5419, acc : 0.6410, auc_score : 0.6258
# Processed Data [ Ridge / MinMaxScaler & PCA(95%)                        ] f1 score : 0.5173, acc : 0.6346, auc_score : 0.6186
# Raw Data       [ Ridge / MinMaxScaler & PCA(99%)                        ] f1 score : 0.5420, acc : 0.6393, auc_score : 0.6244
# Processed Data [ Ridge / MinMaxScaler & PCA(99%)                        ] f1 score : 0.5202, acc : 0.6356, auc_score : 0.6198
#
#
#                               ****************************************************************
#                               ****************             Lasso              ****************
#                               ****************************************************************
#
# Raw Data       [ Lasso / NoScaler                                       ] f1 score : 0.4197, acc : 0.6147, auc_score : 0.5872
# Processed Data [ Lasso / NoScaler                                       ] f1 score : 0.4204, acc : 0.6144, auc_score : 0.5905
# Raw Data       [ Lasso / NoScaler & PCA(90%)                            ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / NoScaler & PCA(90%)                            ] f1 score : 0.4204, acc : 0.6144, auc_score : 0.5905
# Raw Data       [ Lasso / NoScaler & PCA(95%)                            ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Lasso / NoScaler & PCA(95%)                            ] f1 score : 0.4204, acc : 0.6144, auc_score : 0.5905
# Raw Data       [ Lasso / NoScaler & PCA(99%)                            ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ Lasso / NoScaler & PCA(99%)                            ] f1 score : 0.4204, acc : 0.6144, auc_score : 0.5905
# Raw Data       [ Lasso / StandardScaler                                 ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / StandardScaler                                 ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / StandardScaler & PCA(90%)                      ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / StandardScaler & PCA(90%)                      ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / StandardScaler & PCA(95%)                      ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / StandardScaler & PCA(95%)                      ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / StandardScaler & PCA(99%)                      ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / StandardScaler & PCA(99%)                      ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / RobustScaler                                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / RobustScaler                                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / RobustScaler & PCA(90%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / RobustScaler & PCA(90%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / RobustScaler & PCA(95%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / RobustScaler & PCA(95%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / RobustScaler & PCA(99%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / RobustScaler & PCA(99%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / MinMaxScaler                                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / MinMaxScaler                                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / MinMaxScaler & PCA(90%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / MinMaxScaler & PCA(90%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / MinMaxScaler & PCA(95%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / MinMaxScaler & PCA(95%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ Lasso / MinMaxScaler & PCA(99%)                        ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ Lasso / MinMaxScaler & PCA(99%)                        ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
#
#
#                               ****************************************************************
#                               ****************           ElasticNet           ****************
#                               ****************************************************************
#
# Raw Data       [ ElasticNet / NoScaler                                  ] f1 score : 0.5664, acc : 0.6410, auc_score : 0.6301
# Processed Data [ ElasticNet / NoScaler                                  ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# Raw Data       [ ElasticNet / NoScaler & PCA(90%)                       ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / NoScaler & PCA(90%)                       ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# Raw Data       [ ElasticNet / NoScaler & PCA(95%)                       ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ ElasticNet / NoScaler & PCA(95%)                       ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# Raw Data       [ ElasticNet / NoScaler & PCA(99%)                       ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ ElasticNet / NoScaler & PCA(99%)                       ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# Raw Data       [ ElasticNet / StandardScaler                            ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / StandardScaler                            ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / StandardScaler & PCA(90%)                 ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / StandardScaler & PCA(90%)                 ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / StandardScaler & PCA(95%)                 ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / StandardScaler & PCA(95%)                 ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / StandardScaler & PCA(99%)                 ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / StandardScaler & PCA(99%)                 ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / RobustScaler                              ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / RobustScaler                              ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / RobustScaler & PCA(90%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / RobustScaler & PCA(90%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / RobustScaler & PCA(95%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / RobustScaler & PCA(95%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / RobustScaler & PCA(99%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / RobustScaler & PCA(99%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / MinMaxScaler                              ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / MinMaxScaler                              ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / MinMaxScaler & PCA(90%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / MinMaxScaler & PCA(90%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / MinMaxScaler & PCA(95%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / MinMaxScaler & PCA(95%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
# Raw Data       [ ElasticNet / MinMaxScaler & PCA(99%)                   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ ElasticNet / MinMaxScaler & PCA(99%)                   ] f1 score : 0.0000, acc : 0.5419, auc_score : 0.5000
#
#
#                               ****************************************************************
#                               ****************       LogisticRegression       ****************
#                               ****************************************************************
#
# Raw Data       [ LogisticRegression / NoScaler                          ] f1 score : 0.6471, acc : 0.6480, auc_score : 0.6541
# Processed Data [ LogisticRegression / NoScaler                          ] f1 score : 0.6317, acc : 0.6779, auc_score : 0.6721
# Raw Data       [ LogisticRegression / NoScaler & PCA(90%)               ] f1 score : 0.0653, acc : 0.5450, auc_score : 0.4991
# Processed Data [ LogisticRegression / NoScaler & PCA(90%)               ] f1 score : 0.5609, acc : 0.6454, auc_score : 0.6338
# Raw Data       [ LogisticRegression / NoScaler & PCA(95%)               ] f1 score : 0.1334, acc : 0.5413, auc_score : 0.4996
# Processed Data [ LogisticRegression / NoScaler & PCA(95%)               ] f1 score : 0.5588, acc : 0.6447, auc_score : 0.6329
# Raw Data       [ LogisticRegression / NoScaler & PCA(99%)               ] f1 score : 0.4649, acc : 0.4876, auc_score : 0.4882
# Processed Data [ LogisticRegression / NoScaler & PCA(99%)               ] f1 score : 0.6106, acc : 0.6601, auc_score : 0.6540
# Raw Data       [ LogisticRegression / StandardScaler                    ] f1 score : 0.6276, acc : 0.6741, auc_score : 0.6683
# Processed Data [ LogisticRegression / StandardScaler                    ] f1 score : 0.6303, acc : 0.6771, auc_score : 0.6712
# Raw Data       [ LogisticRegression / StandardScaler & PCA(90%)         ] f1 score : 0.5733, acc : 0.6489, auc_score : 0.6376
# Processed Data [ LogisticRegression / StandardScaler & PCA(90%)         ] f1 score : 0.5634, acc : 0.6504, auc_score : 0.6382
# Raw Data       [ LogisticRegression / StandardScaler & PCA(95%)         ] f1 score : 0.5749, acc : 0.6510, auc_score : 0.6395
# Processed Data [ LogisticRegression / StandardScaler & PCA(95%)         ] f1 score : 0.5682, acc : 0.6527, auc_score : 0.6408
# Raw Data       [ LogisticRegression / StandardScaler & PCA(99%)         ] f1 score : 0.5711, acc : 0.6514, auc_score : 0.6391
# Processed Data [ LogisticRegression / StandardScaler & PCA(99%)         ] f1 score : 0.5763, acc : 0.6562, auc_score : 0.6449
# Raw Data       [ LogisticRegression / RobustScaler                      ] f1 score : 0.6103, acc : 0.6625, auc_score : 0.6557
# Processed Data [ LogisticRegression / RobustScaler                      ] f1 score : 0.6303, acc : 0.6771, auc_score : 0.6712
# Raw Data       [ LogisticRegression / RobustScaler & PCA(90%)           ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ LogisticRegression / RobustScaler & PCA(90%)           ] f1 score : 0.6082, acc : 0.6606, auc_score : 0.6540
# Raw Data       [ LogisticRegression / RobustScaler & PCA(95%)           ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LogisticRegression / RobustScaler & PCA(95%)           ] f1 score : 0.6070, acc : 0.6596, auc_score : 0.6529
# Raw Data       [ LogisticRegression / RobustScaler & PCA(99%)           ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LogisticRegression / RobustScaler & PCA(99%)           ] f1 score : 0.6106, acc : 0.6642, auc_score : 0.6573
# Raw Data       [ LogisticRegression / MinMaxScaler                      ] f1 score : 0.6272, acc : 0.6739, auc_score : 0.6681
# Processed Data [ LogisticRegression / MinMaxScaler                      ] f1 score : 0.6302, acc : 0.6771, auc_score : 0.6712
# Raw Data       [ LogisticRegression / MinMaxScaler & PCA(90%)           ] f1 score : 0.5572, acc : 0.6382, auc_score : 0.6263
# Processed Data [ LogisticRegression / MinMaxScaler & PCA(90%)           ] f1 score : 0.5176, acc : 0.6347, auc_score : 0.6187
# Raw Data       [ LogisticRegression / MinMaxScaler & PCA(95%)           ] f1 score : 0.5461, acc : 0.6425, auc_score : 0.6277
# Processed Data [ LogisticRegression / MinMaxScaler & PCA(95%)           ] f1 score : 0.5166, acc : 0.6345, auc_score : 0.6185
# Raw Data       [ LogisticRegression / MinMaxScaler & PCA(99%)           ] f1 score : 0.5460, acc : 0.6405, auc_score : 0.6260
# Processed Data [ LogisticRegression / MinMaxScaler & PCA(99%)           ] f1 score : 0.5193, acc : 0.6354, auc_score : 0.6195
#
#
#                               ****************************************************************
#                               ****************           GaussianNB           ****************
#                               ****************************************************************
#
# Raw Data       [ GaussianNB / NoScaler                                  ] f1 score : 0.6172, acc : 0.4524, auc_score : 0.4999
# Processed Data [ GaussianNB / NoScaler                                  ] f1 score : 0.6568, acc : 0.6610, auc_score : 0.6646
# Raw Data       [ GaussianNB / NoScaler & PCA(90%)                       ] f1 score : 0.6200, acc : 0.4516, auc_score : 0.5004
# Processed Data [ GaussianNB / NoScaler & PCA(90%)                       ] f1 score : 0.5404, acc : 0.6422, auc_score : 0.6281
# Raw Data       [ GaussianNB / NoScaler & PCA(95%)                       ] f1 score : 0.0089, acc : 0.5492, auc_score : 0.5001
# Processed Data [ GaussianNB / NoScaler & PCA(95%)                       ] f1 score : 0.5394, acc : 0.6410, auc_score : 0.6270
# Raw Data       [ GaussianNB / NoScaler & PCA(99%)                       ] f1 score : 0.6183, acc : 0.4519, auc_score : 0.5000
# Processed Data [ GaussianNB / NoScaler & PCA(99%)                       ] f1 score : 0.5802, acc : 0.6524, auc_score : 0.6425
# Raw Data       [ GaussianNB / StandardScaler                            ] f1 score : 0.6205, acc : 0.5195, auc_score : 0.5513
# Processed Data [ GaussianNB / StandardScaler                            ] f1 score : 0.6568, acc : 0.6610, auc_score : 0.6646
# Raw Data       [ GaussianNB / StandardScaler & PCA(90%)                 ] f1 score : 0.5912, acc : 0.6511, auc_score : 0.6429
# Processed Data [ GaussianNB / StandardScaler & PCA(90%)                 ] f1 score : 0.5486, acc : 0.6485, auc_score : 0.6344
# Raw Data       [ GaussianNB / StandardScaler & PCA(95%)                 ] f1 score : 0.5905, acc : 0.6486, auc_score : 0.6408
# Processed Data [ GaussianNB / StandardScaler & PCA(95%)                 ] f1 score : 0.5557, acc : 0.6518, auc_score : 0.6381
# Raw Data       [ GaussianNB / StandardScaler & PCA(99%)                 ] f1 score : 0.5844, acc : 0.6538, auc_score : 0.6436
# Processed Data [ GaussianNB / StandardScaler & PCA(99%)                 ] f1 score : 0.5801, acc : 0.6592, auc_score : 0.6480
# Raw Data       [ GaussianNB / RobustScaler                              ] f1 score : 0.6208, acc : 0.5200, auc_score : 0.5517
# Processed Data [ GaussianNB / RobustScaler                              ] f1 score : 0.6568, acc : 0.6610, auc_score : 0.6646
# Raw Data       [ GaussianNB / RobustScaler & PCA(90%)                   ] f1 score : 0.6201, acc : 0.4516, auc_score : 0.5005
# Processed Data [ GaussianNB / RobustScaler & PCA(90%)                   ] f1 score : 0.6237, acc : 0.6634, auc_score : 0.6592
# Raw Data       [ GaussianNB / RobustScaler & PCA(95%)                   ] f1 score : 0.0062, acc : 0.5488, auc_score : 0.4996
# Processed Data [ GaussianNB / RobustScaler & PCA(95%)                   ] f1 score : 0.6258, acc : 0.6641, auc_score : 0.6601
# Raw Data       [ GaussianNB / RobustScaler & PCA(99%)                   ] f1 score : 0.6182, acc : 0.4519, auc_score : 0.4999
# Processed Data [ GaussianNB / RobustScaler & PCA(99%)                   ] f1 score : 0.6228, acc : 0.6654, auc_score : 0.6606
# Raw Data       [ GaussianNB / MinMaxScaler                              ] f1 score : 0.6205, acc : 0.5195, auc_score : 0.5513
# Processed Data [ GaussianNB / MinMaxScaler                              ] f1 score : 0.6568, acc : 0.6610, auc_score : 0.6646
# Raw Data       [ GaussianNB / MinMaxScaler & PCA(90%)                   ] f1 score : 0.5518, acc : 0.6349, auc_score : 0.6226
# Processed Data [ GaussianNB / MinMaxScaler & PCA(90%)                   ] f1 score : 0.5130, acc : 0.6344, auc_score : 0.6178
# Raw Data       [ GaussianNB / MinMaxScaler & PCA(95%)                   ] f1 score : 0.5547, acc : 0.6396, auc_score : 0.6268
# Processed Data [ GaussianNB / MinMaxScaler & PCA(95%)                   ] f1 score : 0.5119, acc : 0.6341, auc_score : 0.6175
# Raw Data       [ GaussianNB / MinMaxScaler & PCA(99%)                   ] f1 score : 0.5549, acc : 0.6393, auc_score : 0.6267
# Processed Data [ GaussianNB / MinMaxScaler & PCA(99%)                   ] f1 score : 0.5094, acc : 0.6308, auc_score : 0.6144
#
#
#                               ****************************************************************
#                               ****************   LinearDiscriminantAnalysis   ****************
#                               ****************************************************************
#
# Raw Data       [ LinearDiscriminantAnalysis / NoScaler                  ] f1 score : 0.6257, acc : 0.6731, auc_score : 0.6671
# Processed Data [ LinearDiscriminantAnalysis / NoScaler                  ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# Raw Data       [ LinearDiscriminantAnalysis / NoScaler & PCA(90%)       ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ LinearDiscriminantAnalysis / NoScaler & PCA(90%)       ] f1 score : 0.5564, acc : 0.6445, auc_score : 0.6323
# Raw Data       [ LinearDiscriminantAnalysis / NoScaler & PCA(95%)       ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearDiscriminantAnalysis / NoScaler & PCA(95%)       ] f1 score : 0.5540, acc : 0.6436, auc_score : 0.6312
# Raw Data       [ LinearDiscriminantAnalysis / NoScaler & PCA(99%)       ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearDiscriminantAnalysis / NoScaler & PCA(99%)       ] f1 score : 0.6098, acc : 0.6596, auc_score : 0.6535
# Raw Data       [ LinearDiscriminantAnalysis / StandardScaler            ] f1 score : 0.6257, acc : 0.6731, auc_score : 0.6671
# Processed Data [ LinearDiscriminantAnalysis / StandardScaler            ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# Raw Data       [ LinearDiscriminantAnalysis / StandardScaler & PCA(90%) ] f1 score : 0.5715, acc : 0.6489, auc_score : 0.6372
# Processed Data [ LinearDiscriminantAnalysis / StandardScaler & PCA(90%) ] f1 score : 0.5674, acc : 0.6532, auc_score : 0.6411
# Raw Data       [ LinearDiscriminantAnalysis / StandardScaler & PCA(95%) ] f1 score : 0.5727, acc : 0.6504, auc_score : 0.6387
# Processed Data [ LinearDiscriminantAnalysis / StandardScaler & PCA(95%) ] f1 score : 0.5671, acc : 0.6526, auc_score : 0.6406
# Raw Data       [ LinearDiscriminantAnalysis / StandardScaler & PCA(99%) ] f1 score : 0.5678, acc : 0.6497, auc_score : 0.6372
# Processed Data [ LinearDiscriminantAnalysis / StandardScaler & PCA(99%) ] f1 score : 0.5678, acc : 0.6541, auc_score : 0.6419
# Raw Data       [ LinearDiscriminantAnalysis / RobustScaler              ] f1 score : 0.6257, acc : 0.6731, auc_score : 0.6671
# Processed Data [ LinearDiscriminantAnalysis / RobustScaler              ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# Raw Data       [ LinearDiscriminantAnalysis / RobustScaler & PCA(90%)   ] f1 score : 0.0000, acc : 0.5495, auc_score : 0.5000
# Processed Data [ LinearDiscriminantAnalysis / RobustScaler & PCA(90%)   ] f1 score : 0.6078, acc : 0.6603, auc_score : 0.6537
# Raw Data       [ LinearDiscriminantAnalysis / RobustScaler & PCA(95%)   ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearDiscriminantAnalysis / RobustScaler & PCA(95%)   ] f1 score : 0.6070, acc : 0.6596, auc_score : 0.6530
# Raw Data       [ LinearDiscriminantAnalysis / RobustScaler & PCA(99%)   ] f1 score : 0.0004, acc : 0.5494, auc_score : 0.4999
# Processed Data [ LinearDiscriminantAnalysis / RobustScaler & PCA(99%)   ] f1 score : 0.6082, acc : 0.6636, auc_score : 0.6564
# Raw Data       [ LinearDiscriminantAnalysis / MinMaxScaler              ] f1 score : 0.6257, acc : 0.6731, auc_score : 0.6671
# Processed Data [ LinearDiscriminantAnalysis / MinMaxScaler              ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# Raw Data       [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(90%)   ] f1 score : 0.5565, acc : 0.6382, auc_score : 0.6261
# Processed Data [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(90%)   ] f1 score : 0.5184, acc : 0.6350, auc_score : 0.6191
# Raw Data       [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(95%)   ] f1 score : 0.5420, acc : 0.6410, auc_score : 0.6257
# Processed Data [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(95%)   ] f1 score : 0.5175, acc : 0.6347, auc_score : 0.6187
# Raw Data       [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(99%)   ] f1 score : 0.5423, acc : 0.6394, auc_score : 0.6245
# Processed Data [ LinearDiscriminantAnalysis / MinMaxScaler & PCA(99%)   ] f1 score : 0.5202, acc : 0.6355, auc_score : 0.6197
#
#
#                               ****************************************************************
#                               ****************           LinearSVC            ****************
#                               ****************************************************************
#
# Raw Data       [ LinearSVC / NoScaler                                   ] f1 score : 0.6325, acc : 0.5572, auc_score : 0.5832
# Processed Data [ LinearSVC / NoScaler                                   ] f1 score : 0.7173, acc : 0.6826, auc_score : 0.6978
# Raw Data       [ LinearSVC / NoScaler & PCA(90%)                        ] f1 score : 0.6127, acc : 0.4540, auc_score : 0.4995
# Processed Data [ LinearSVC / NoScaler & PCA(90%)                        ] f1 score : 0.5718, acc : 0.6480, auc_score : 0.6376
# Raw Data       [ LinearSVC / NoScaler & PCA(95%)                        ] f1 score : 0.5914, acc : 0.4600, auc_score : 0.4967
# Processed Data [ LinearSVC / NoScaler & PCA(95%)                        ] f1 score : 0.5644, acc : 0.6460, auc_score : 0.6347
# Raw Data       [ LinearSVC / NoScaler & PCA(99%)                        ] f1 score : 0.1783, acc : 0.5402, auc_score : 0.5015
# Processed Data [ LinearSVC / NoScaler & PCA(99%)                        ] f1 score : 0.6151, acc : 0.6605, auc_score : 0.6553
# Raw Data       [ LinearSVC / StandardScaler                             ] f1 score : 0.6247, acc : 0.6715, auc_score : 0.6657
# Processed Data [ LinearSVC / StandardScaler                             ] f1 score : 0.6262, acc : 0.6746, auc_score : 0.6685
# Raw Data       [ LinearSVC / StandardScaler & PCA(90%)                  ] f1 score : 0.5702, acc : 0.6482, auc_score : 0.6364
# Processed Data [ LinearSVC / StandardScaler & PCA(90%)                  ] f1 score : 0.5634, acc : 0.6512, auc_score : 0.6389
# Raw Data       [ LinearSVC / StandardScaler & PCA(95%)                  ] f1 score : 0.5722, acc : 0.6500, auc_score : 0.6382
# Processed Data [ LinearSVC / StandardScaler & PCA(95%)                  ] f1 score : 0.5622, acc : 0.6508, auc_score : 0.6383
# Raw Data       [ LinearSVC / StandardScaler & PCA(99%)                  ] f1 score : 0.5670, acc : 0.6492, auc_score : 0.6366
# Processed Data [ LinearSVC / StandardScaler & PCA(99%)                  ] f1 score : 0.5705, acc : 0.6550, auc_score : 0.6430
# Raw Data       [ LinearSVC / RobustScaler                               ] f1 score : 0.6228, acc : 0.6713, auc_score : 0.6651
# Processed Data [ LinearSVC / RobustScaler                               ] f1 score : 0.6259, acc : 0.6743, auc_score : 0.6682
# Raw Data       [ LinearSVC / RobustScaler & PCA(90%)                    ] f1 score : 0.0220, acc : 0.5466, auc_score : 0.4984
# Processed Data [ LinearSVC / RobustScaler & PCA(90%)                    ] f1 score : 0.6072, acc : 0.6599, auc_score : 0.6533
# Raw Data       [ LinearSVC / RobustScaler & PCA(95%)                    ] f1 score : 0.0319, acc : 0.5471, auc_score : 0.4993
# Processed Data [ LinearSVC / RobustScaler & PCA(95%)                    ] f1 score : 0.6072, acc : 0.6598, auc_score : 0.6532
# Raw Data       [ LinearSVC / RobustScaler & PCA(99%)                    ] f1 score : 0.0365, acc : 0.5452, auc_score : 0.4978
# Processed Data [ LinearSVC / RobustScaler & PCA(99%)                    ] f1 score : 0.6076, acc : 0.6633, auc_score : 0.6560
# Raw Data       [ LinearSVC / MinMaxScaler                               ] f1 score : 0.6254, acc : 0.6730, auc_score : 0.6670
# Processed Data [ LinearSVC / MinMaxScaler                               ] f1 score : 0.6259, acc : 0.6743, auc_score : 0.6682
# Raw Data       [ LinearSVC / MinMaxScaler & PCA(90%)                    ] f1 score : 0.5561, acc : 0.6381, auc_score : 0.6259
# Processed Data [ LinearSVC / MinMaxScaler & PCA(90%)                    ] f1 score : 0.5180, acc : 0.6348, auc_score : 0.6189
# Raw Data       [ LinearSVC / MinMaxScaler & PCA(95%)                    ] f1 score : 0.5419, acc : 0.6410, auc_score : 0.6258
# Processed Data [ LinearSVC / MinMaxScaler & PCA(95%)                    ] f1 score : 0.5173, acc : 0.6346, auc_score : 0.6186
# Raw Data       [ LinearSVC / MinMaxScaler & PCA(99%)                    ] f1 score : 0.5422, acc : 0.6395, auc_score : 0.6245
# Processed Data [ LinearSVC / MinMaxScaler & PCA(99%)                    ] f1 score : 0.5202, acc : 0.6356, auc_score : 0.6198
#
#
#                               ****************************************************************
#                               ****************     DecisionTreeClassifier     ****************
#                               ****************************************************************
#
# Raw Data       [ DecisionTreeClassifier / NoScaler                      ] f1 score : 0.5576, acc : 0.6028, auc_score : 0.5986
# Processed Data [ DecisionTreeClassifier / NoScaler                      ] f1 score : 0.5718, acc : 0.6139, auc_score : 0.6100
# Raw Data       [ DecisionTreeClassifier / NoScaler & PCA(90%)           ] f1 score : 0.4535, acc : 0.5058, auc_score : 0.5012
# Processed Data [ DecisionTreeClassifier / NoScaler & PCA(90%)           ] f1 score : 0.5559, acc : 0.5969, auc_score : 0.5934
# Raw Data       [ DecisionTreeClassifier / NoScaler & PCA(95%)           ] f1 score : 0.4718, acc : 0.5210, auc_score : 0.5168
# Processed Data [ DecisionTreeClassifier / NoScaler & PCA(95%)           ] f1 score : 0.5571, acc : 0.5930, auc_score : 0.5903
# Raw Data       [ DecisionTreeClassifier / NoScaler & PCA(99%)           ] f1 score : 0.4559, acc : 0.5111, auc_score : 0.5060
# Processed Data [ DecisionTreeClassifier / NoScaler & PCA(99%)           ] f1 score : 0.5655, acc : 0.6042, auc_score : 0.6010
# Raw Data       [ DecisionTreeClassifier / StandardScaler                ] f1 score : 0.5624, acc : 0.6063, auc_score : 0.6022
# Processed Data [ DecisionTreeClassifier / StandardScaler                ] f1 score : 0.5706, acc : 0.6132, auc_score : 0.6092
# Raw Data       [ DecisionTreeClassifier / StandardScaler & PCA(90%)     ] f1 score : 0.5180, acc : 0.5638, auc_score : 0.5599
# Processed Data [ DecisionTreeClassifier / StandardScaler & PCA(90%)     ] f1 score : 0.5500, acc : 0.5918, auc_score : 0.5882
# Raw Data       [ DecisionTreeClassifier / StandardScaler & PCA(95%)     ] f1 score : 0.5264, acc : 0.5651, auc_score : 0.5625
# Processed Data [ DecisionTreeClassifier / StandardScaler & PCA(95%)     ] f1 score : 0.5481, acc : 0.5935, auc_score : 0.5892
# Raw Data       [ DecisionTreeClassifier / StandardScaler & PCA(99%)     ] f1 score : 0.5354, acc : 0.5716, auc_score : 0.5695
# Processed Data [ DecisionTreeClassifier / StandardScaler & PCA(99%)     ] f1 score : 0.5598, acc : 0.6029, auc_score : 0.5989
# Raw Data       [ DecisionTreeClassifier / RobustScaler                  ] f1 score : 0.5613, acc : 0.6061, auc_score : 0.6019
# Processed Data [ DecisionTreeClassifier / RobustScaler                  ] f1 score : 0.5735, acc : 0.6149, auc_score : 0.6110
# Raw Data       [ DecisionTreeClassifier / RobustScaler & PCA(90%)       ] f1 score : 0.4550, acc : 0.5035, auc_score : 0.4996
# Processed Data [ DecisionTreeClassifier / RobustScaler & PCA(90%)       ] f1 score : 0.5479, acc : 0.5900, auc_score : 0.5863
# Raw Data       [ DecisionTreeClassifier / RobustScaler & PCA(95%)       ] f1 score : 0.4737, acc : 0.5195, auc_score : 0.5160
# Processed Data [ DecisionTreeClassifier / RobustScaler & PCA(95%)       ] f1 score : 0.5622, acc : 0.6000, auc_score : 0.5970
# Raw Data       [ DecisionTreeClassifier / RobustScaler & PCA(99%)       ] f1 score : 0.4617, acc : 0.5101, auc_score : 0.5061
# Processed Data [ DecisionTreeClassifier / RobustScaler & PCA(99%)       ] f1 score : 0.5614, acc : 0.6031, auc_score : 0.5993
# Raw Data       [ DecisionTreeClassifier / MinMaxScaler                  ] f1 score : 0.5629, acc : 0.6047, auc_score : 0.6011
# Processed Data [ DecisionTreeClassifier / MinMaxScaler                  ] f1 score : 0.5740, acc : 0.6159, auc_score : 0.6120
# Raw Data       [ DecisionTreeClassifier / MinMaxScaler & PCA(90%)       ] f1 score : 0.5106, acc : 0.5572, auc_score : 0.5532
# Processed Data [ DecisionTreeClassifier / MinMaxScaler & PCA(90%)       ] f1 score : 0.5644, acc : 0.6019, auc_score : 0.5989
# Raw Data       [ DecisionTreeClassifier / MinMaxScaler & PCA(95%)       ] f1 score : 0.5216, acc : 0.5648, auc_score : 0.5614
# Processed Data [ DecisionTreeClassifier / MinMaxScaler & PCA(95%)       ] f1 score : 0.5667, acc : 0.6071, auc_score : 0.6035
# Raw Data       [ DecisionTreeClassifier / MinMaxScaler & PCA(99%)       ] f1 score : 0.5304, acc : 0.5687, auc_score : 0.5662
# Processed Data [ DecisionTreeClassifier / MinMaxScaler & PCA(99%)       ] f1 score : 0.5600, acc : 0.6032, auc_score : 0.5992
#
#
#                               ****************************************************************
#                               ****************      KNeighborsClassifier      ****************
#                               ****************************************************************
#
# Raw Data       [ KNeighborsClassifier / NoScaler                        ] f1 score : 0.4664, acc : 0.5162, auc_score : 0.5120
# Processed Data [ KNeighborsClassifier / NoScaler                        ] f1 score : 0.6106, acc : 0.6372, auc_score : 0.6359
# Raw Data       [ KNeighborsClassifier / NoScaler & PCA(90%)             ] f1 score : 0.4364, acc : 0.5120, auc_score : 0.5037
# Processed Data [ KNeighborsClassifier / NoScaler & PCA(90%)             ] f1 score : 0.5886, acc : 0.6229, auc_score : 0.6203
# Raw Data       [ KNeighborsClassifier / NoScaler & PCA(95%)             ] f1 score : 0.4448, acc : 0.5144, auc_score : 0.5069
# Processed Data [ KNeighborsClassifier / NoScaler & PCA(95%)             ] f1 score : 0.5940, acc : 0.6294, auc_score : 0.6265
# Raw Data       [ KNeighborsClassifier / NoScaler & PCA(99%)             ] f1 score : 0.4507, acc : 0.5073, auc_score : 0.5021
# Processed Data [ KNeighborsClassifier / NoScaler & PCA(99%)             ] f1 score : 0.6054, acc : 0.6353, auc_score : 0.6334
# Raw Data       [ KNeighborsClassifier / StandardScaler                  ] f1 score : 0.5596, acc : 0.6166, auc_score : 0.6098
# Processed Data [ KNeighborsClassifier / StandardScaler                  ] f1 score : 0.6034, acc : 0.6462, auc_score : 0.6417
# Raw Data       [ KNeighborsClassifier / StandardScaler & PCA(90%)       ] f1 score : 0.5596, acc : 0.6050, auc_score : 0.6007
# Processed Data [ KNeighborsClassifier / StandardScaler & PCA(90%)       ] f1 score : 0.6031, acc : 0.6396, auc_score : 0.6364
# Raw Data       [ KNeighborsClassifier / StandardScaler & PCA(95%)       ] f1 score : 0.5644, acc : 0.6092, auc_score : 0.6049
# Processed Data [ KNeighborsClassifier / StandardScaler & PCA(95%)       ] f1 score : 0.6081, acc : 0.6445, auc_score : 0.6412
# Raw Data       [ KNeighborsClassifier / StandardScaler & PCA(99%)       ] f1 score : 0.5815, acc : 0.6221, auc_score : 0.6185
# Processed Data [ KNeighborsClassifier / StandardScaler & PCA(99%)       ] f1 score : 0.6102, acc : 0.6469, auc_score : 0.6436
# Raw Data       [ KNeighborsClassifier / RobustScaler                    ] f1 score : 0.5584, acc : 0.6011, auc_score : 0.5974
# Processed Data [ KNeighborsClassifier / RobustScaler                    ] f1 score : 0.6104, acc : 0.6466, auc_score : 0.6433
# Raw Data       [ KNeighborsClassifier / RobustScaler & PCA(90%)         ] f1 score : 0.4335, acc : 0.5065, auc_score : 0.4987
# Processed Data [ KNeighborsClassifier / RobustScaler & PCA(90%)         ] f1 score : 0.5897, acc : 0.6271, auc_score : 0.6238
# Raw Data       [ KNeighborsClassifier / RobustScaler & PCA(95%)         ] f1 score : 0.4363, acc : 0.5100, auc_score : 0.5020
# Processed Data [ KNeighborsClassifier / RobustScaler & PCA(95%)         ] f1 score : 0.5969, acc : 0.6352, auc_score : 0.6317
# Raw Data       [ KNeighborsClassifier / RobustScaler & PCA(99%)         ] f1 score : 0.4490, acc : 0.5085, auc_score : 0.5027
# Processed Data [ KNeighborsClassifier / RobustScaler & PCA(99%)         ] f1 score : 0.6038, acc : 0.6424, auc_score : 0.6387
# Raw Data       [ KNeighborsClassifier / MinMaxScaler                    ] f1 score : 0.5587, acc : 0.6157, auc_score : 0.6089
# Processed Data [ KNeighborsClassifier / MinMaxScaler                    ] f1 score : 0.6038, acc : 0.6451, auc_score : 0.6409
# Raw Data       [ KNeighborsClassifier / MinMaxScaler & PCA(90%)         ] f1 score : 0.5523, acc : 0.6053, auc_score : 0.5994
# Processed Data [ KNeighborsClassifier / MinMaxScaler & PCA(90%)         ] f1 score : 0.6096, acc : 0.6468, auc_score : 0.6433
# Raw Data       [ KNeighborsClassifier / MinMaxScaler & PCA(95%)         ] f1 score : 0.5505, acc : 0.6045, auc_score : 0.5985
# Processed Data [ KNeighborsClassifier / MinMaxScaler & PCA(95%)         ] f1 score : 0.6110, acc : 0.6461, auc_score : 0.6431
# Raw Data       [ KNeighborsClassifier / MinMaxScaler & PCA(99%)         ] f1 score : 0.5644, acc : 0.6135, auc_score : 0.6083
# Processed Data [ KNeighborsClassifier / MinMaxScaler & PCA(99%)         ] f1 score : 0.6239, acc : 0.6552, auc_score : 0.6528
#
#
#                               ****************************************************************
#                               ****************     RandomForestClassifier     ****************
#                               ****************************************************************
#
# Raw Data       [ RandomForestClassifier / NoScaler                      ] f1 score : 0.6643, acc : 0.6799, auc_score : 0.6820
# Processed Data [ RandomForestClassifier / NoScaler                      ] f1 score : 0.6753, acc : 0.6894, auc_score : 0.6906
# Raw Data       [ RandomForestClassifier / NoScaler & PCA(90%)           ] f1 score : 0.4084, acc : 0.5253, auc_score : 0.5107
# Processed Data [ RandomForestClassifier / NoScaler & PCA(90%)           ] f1 score : 0.6192, acc : 0.6423, auc_score : 0.6417
# Raw Data       [ RandomForestClassifier / NoScaler & PCA(95%)           ] f1 score : 0.3960, acc : 0.5280, auc_score : 0.5114
# Processed Data [ RandomForestClassifier / NoScaler & PCA(95%)           ] f1 score : 0.6250, acc : 0.6451, auc_score : 0.6451
# Raw Data       [ RandomForestClassifier / NoScaler & PCA(99%)           ] f1 score : 0.3791, acc : 0.5402, auc_score : 0.5196
# Processed Data [ RandomForestClassifier / NoScaler & PCA(99%)           ] f1 score : 0.6583, acc : 0.6742, auc_score : 0.6750
# Raw Data       [ RandomForestClassifier / StandardScaler                ] f1 score : 0.6675, acc : 0.6818, auc_score : 0.6843
# Processed Data [ RandomForestClassifier / StandardScaler                ] f1 score : 0.6708, acc : 0.6861, auc_score : 0.6870
# Raw Data       [ RandomForestClassifier / StandardScaler & PCA(90%)     ] f1 score : 0.5807, acc : 0.6289, auc_score : 0.6236
# Processed Data [ RandomForestClassifier / StandardScaler & PCA(90%)     ] f1 score : 0.6233, acc : 0.6558, auc_score : 0.6532
# Raw Data       [ RandomForestClassifier / StandardScaler & PCA(95%)     ] f1 score : 0.5896, acc : 0.6389, auc_score : 0.6332
# Processed Data [ RandomForestClassifier / StandardScaler & PCA(95%)     ] f1 score : 0.6384, acc : 0.6670, auc_score : 0.6650
# Raw Data       [ RandomForestClassifier / StandardScaler & PCA(99%)     ] f1 score : 0.6195, acc : 0.6605, auc_score : 0.6562
# Processed Data [ RandomForestClassifier / StandardScaler & PCA(99%)     ] f1 score : 0.6466, acc : 0.6766, auc_score : 0.6742
# Raw Data       [ RandomForestClassifier / RobustScaler                  ] f1 score : 0.6684, acc : 0.6822, auc_score : 0.6848
# Processed Data [ RandomForestClassifier / RobustScaler                  ] f1 score : 0.6777, acc : 0.6916, auc_score : 0.6928
# Raw Data       [ RandomForestClassifier / RobustScaler & PCA(90%)       ] f1 score : 0.4045, acc : 0.5257, auc_score : 0.5106
# Processed Data [ RandomForestClassifier / RobustScaler & PCA(90%)       ] f1 score : 0.6238, acc : 0.6541, auc_score : 0.6520
# Raw Data       [ RandomForestClassifier / RobustScaler & PCA(95%)       ] f1 score : 0.4006, acc : 0.5332, auc_score : 0.5163
# Processed Data [ RandomForestClassifier / RobustScaler & PCA(95%)       ] f1 score : 0.6344, acc : 0.6587, auc_score : 0.6578
# Raw Data       [ RandomForestClassifier / RobustScaler & PCA(99%)       ] f1 score : 0.3658, acc : 0.5337, auc_score : 0.5125
# Processed Data [ RandomForestClassifier / RobustScaler & PCA(99%)       ] f1 score : 0.6492, acc : 0.6693, auc_score : 0.6692
# Raw Data       [ RandomForestClassifier / MinMaxScaler                  ] f1 score : 0.6624, acc : 0.6793, auc_score : 0.6811
# Processed Data [ RandomForestClassifier / MinMaxScaler                  ] f1 score : 0.6792, acc : 0.6924, auc_score : 0.6938
# Raw Data       [ RandomForestClassifier / MinMaxScaler & PCA(90%)       ] f1 score : 0.5636, acc : 0.6215, auc_score : 0.6144
# Processed Data [ RandomForestClassifier / MinMaxScaler & PCA(90%)       ] f1 score : 0.6176, acc : 0.6539, auc_score : 0.6505
# Raw Data       [ RandomForestClassifier / MinMaxScaler & PCA(95%)       ] f1 score : 0.5707, acc : 0.6292, auc_score : 0.6218
# Processed Data [ RandomForestClassifier / MinMaxScaler & PCA(95%)       ] f1 score : 0.6231, acc : 0.6592, auc_score : 0.6558
# Raw Data       [ RandomForestClassifier / MinMaxScaler & PCA(99%)       ] f1 score : 0.5855, acc : 0.6417, auc_score : 0.6345
# Processed Data [ RandomForestClassifier / MinMaxScaler & PCA(99%)       ] f1 score : 0.6367, acc : 0.6666, auc_score : 0.6644
#
#
#                               ****************************************************************
#                               ****************       AdaBoostClassifier       ****************
#                               ****************************************************************
#
# Raw Data       [ AdaBoostClassifier / NoScaler                          ] f1 score : 0.6803, acc : 0.6902, auc_score : 0.6939
# ...
# Processed Data [ GradientBoostingClassifier / MinMaxScaler & PCA(90%)   ] f1 score : 0.6367, acc : 0.6667, auc_score : 0.6644
# Raw Data       [ GradientBoostingClassifier / MinMaxScaler & PCA(95%)   ] f1 score : 0.5608, acc : 0.6421, auc_score : 0.6299
# Processed Data [ GradientBoostingClassifier / MinMaxScaler & PCA(95%)   ] f1 score : 0.6406, acc : 0.6714, auc_score : 0.6689
# Raw Data       [ GradientBoostingClassifier / MinMaxScaler & PCA(99%)   ] f1 score : 0.5691, acc : 0.6468, auc_score : 0.6352
# Processed Data [ GradientBoostingClassifier / MinMaxScaler & PCA(99%)   ] f1 score : 0.6554, acc : 0.6802, auc_score : 0.6790
#
#
#                               ****************************************************************
#                               ****************       BaggingClassifier        ****************
#                               ****************************************************************
#
# Raw Data       [ BaggingClassifier / NoScaler                           ] f1 score : 0.6021, acc : 0.6547, auc_score : 0.6479
# Processed Data [ BaggingClassifier / NoScaler                           ] f1 score : 0.6030, acc : 0.6539, auc_score : 0.6477
# Raw Data       [ BaggingClassifier / NoScaler & PCA(90%)                ] f1 score : 0.3799, acc : 0.5225, auc_score : 0.5047
# Processed Data [ BaggingClassifier / NoScaler & PCA(90%)                ] f1 score : 0.5588, acc : 0.6220, auc_score : 0.6143
# Raw Data       [ BaggingClassifier / NoScaler & PCA(95%)                ] f1 score : 0.3725, acc : 0.5215, auc_score : 0.5029
# Processed Data [ BaggingClassifier / NoScaler & PCA(95%)                ] f1 score : 0.5602, acc : 0.6216, auc_score : 0.6142
# Raw Data       [ BaggingClassifier / NoScaler & PCA(99%)                ] f1 score : 0.3764, acc : 0.5293, auc_score : 0.5100
# Processed Data [ BaggingClassifier / NoScaler & PCA(99%)                ] f1 score : 0.5932, acc : 0.6512, auc_score : 0.6438
# Raw Data       [ BaggingClassifier / StandardScaler                     ] f1 score : 0.5863, acc : 0.6425, auc_score : 0.6353
# Processed Data [ BaggingClassifier / StandardScaler                     ] f1 score : 0.5966, acc : 0.6520, auc_score : 0.6450
# Raw Data       [ BaggingClassifier / StandardScaler & PCA(90%)          ] f1 score : 0.5285, acc : 0.6082, auc_score : 0.5973
# Processed Data [ BaggingClassifier / StandardScaler & PCA(90%)          ] f1 score : 0.5635, acc : 0.6332, auc_score : 0.6242
# Raw Data       [ BaggingClassifier / StandardScaler & PCA(95%)          ] f1 score : 0.5284, acc : 0.6109, auc_score : 0.5995
# Processed Data [ BaggingClassifier / StandardScaler & PCA(95%)          ] f1 score : 0.5678, acc : 0.6303, auc_score : 0.6226
# Raw Data       [ BaggingClassifier / StandardScaler & PCA(99%)          ] f1 score : 0.5507, acc : 0.6273, auc_score : 0.6164
# Processed Data [ BaggingClassifier / StandardScaler & PCA(99%)          ] f1 score : 0.5763, acc : 0.6418, auc_score : 0.6333
# Raw Data       [ BaggingClassifier / RobustScaler                       ] f1 score : 0.5873, acc : 0.6434, auc_score : 0.6362
# Processed Data [ BaggingClassifier / RobustScaler                       ] f1 score : 0.5867, acc : 0.6428, auc_score : 0.6359
# Raw Data       [ BaggingClassifier / RobustScaler & PCA(90%)            ] f1 score : 0.3738, acc : 0.5230, auc_score : 0.5043
# Processed Data [ BaggingClassifier / RobustScaler & PCA(90%)            ] f1 score : 0.5610, acc : 0.6286, auc_score : 0.6200
# Raw Data       [ BaggingClassifier / RobustScaler & PCA(95%)            ] f1 score : 0.3833, acc : 0.5293, auc_score : 0.5109
# Processed Data [ BaggingClassifier / RobustScaler & PCA(95%)            ] f1 score : 0.5701, acc : 0.6320, auc_score : 0.6243
# Raw Data       [ BaggingClassifier / RobustScaler & PCA(99%)            ] f1 score : 0.3602, acc : 0.5249, auc_score : 0.5044
# Processed Data [ BaggingClassifier / RobustScaler & PCA(99%)            ] f1 score : 0.5738, acc : 0.6391, auc_score : 0.6307
# Raw Data       [ BaggingClassifier / MinMaxScaler                       ] f1 score : 0.5871, acc : 0.6446, auc_score : 0.6370
# Processed Data [ BaggingClassifier / MinMaxScaler                       ] f1 score : 0.5993, acc : 0.6531, auc_score : 0.6464
# Raw Data       [ BaggingClassifier / MinMaxScaler & PCA(90%)            ] f1 score : 0.5136, acc : 0.6048, auc_score : 0.5920
# Processed Data [ BaggingClassifier / MinMaxScaler & PCA(90%)            ] f1 score : 0.5717, acc : 0.6349, auc_score : 0.6269
# Raw Data       [ BaggingClassifier / MinMaxScaler & PCA(95%)            ] f1 score : 0.5217, acc : 0.6100, auc_score : 0.5976
# Processed Data [ BaggingClassifier / MinMaxScaler & PCA(95%)            ] f1 score : 0.5774, acc : 0.6396, auc_score : 0.6317
# Raw Data       [ BaggingClassifier / MinMaxScaler & PCA(99%)            ] f1 score : 0.5332, acc : 0.6202, auc_score : 0.6077
# Processed Data [ BaggingClassifier / MinMaxScaler & PCA(99%)            ] f1 score : 0.5846, acc : 0.6432, auc_score : 0.6359
#
#
#                               ****************************************************************
#                               ****************         LGBMClassifier         ****************
#                               ****************************************************************
#
# Raw Data       [ LGBMClassifier / NoScaler                              ] f1 score : 0.6876, acc : 0.6916, auc_score : 0.6971
# Processed Data [ LGBMClassifier / NoScaler                              ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# Raw Data       [ LGBMClassifier / NoScaler & PCA(90%)                   ] f1 score : 0.2852, acc : 0.5424, auc_score : 0.5118
# Processed Data [ LGBMClassifier / NoScaler & PCA(90%)                   ] f1 score : 0.6824, acc : 0.6698, auc_score : 0.6779
# Raw Data       [ LGBMClassifier / NoScaler & PCA(95%)                   ] f1 score : 0.3162, acc : 0.5466, auc_score : 0.5183
# Processed Data [ LGBMClassifier / NoScaler & PCA(95%)                   ] f1 score : 0.6791, acc : 0.6714, auc_score : 0.6782
# Raw Data       [ LGBMClassifier / NoScaler & PCA(99%)                   ] f1 score : 0.3344, acc : 0.5461, auc_score : 0.5197
# Processed Data [ LGBMClassifier / NoScaler & PCA(99%)                   ] f1 score : 0.6870, acc : 0.6861, auc_score : 0.6912
# Raw Data       [ LGBMClassifier / StandardScaler                        ] f1 score : 0.6885, acc : 0.6919, auc_score : 0.6977
# Processed Data [ LGBMClassifier / StandardScaler                        ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# Raw Data       [ LGBMClassifier / StandardScaler & PCA(90%)             ] f1 score : 0.6164, acc : 0.6578, auc_score : 0.6535
# Processed Data [ LGBMClassifier / StandardScaler & PCA(90%)             ] f1 score : 0.6679, acc : 0.6810, auc_score : 0.6825
# Raw Data       [ LGBMClassifier / StandardScaler & PCA(95%)             ] f1 score : 0.6163, acc : 0.6590, auc_score : 0.6544
# Processed Data [ LGBMClassifier / StandardScaler & PCA(95%)             ] f1 score : 0.6697, acc : 0.6838, auc_score : 0.6851
# Raw Data       [ LGBMClassifier / StandardScaler & PCA(99%)             ] f1 score : 0.6327, acc : 0.6665, auc_score : 0.6639
# Processed Data [ LGBMClassifier / StandardScaler & PCA(99%)             ] f1 score : 0.6670, acc : 0.6804, auc_score : 0.6818
# Raw Data       [ LGBMClassifier / RobustScaler                          ] f1 score : 0.6864, acc : 0.6899, auc_score : 0.6956
# Processed Data [ LGBMClassifier / RobustScaler                          ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# Raw Data       [ LGBMClassifier / RobustScaler & PCA(90%)               ] f1 score : 0.2906, acc : 0.5424, auc_score : 0.5123
# Processed Data [ LGBMClassifier / RobustScaler & PCA(90%)               ] f1 score : 0.6711, acc : 0.6787, auc_score : 0.6816
# Raw Data       [ LGBMClassifier / RobustScaler & PCA(95%)               ] f1 score : 0.3138, acc : 0.5473, auc_score : 0.5187
# Processed Data [ LGBMClassifier / RobustScaler & PCA(95%)               ] f1 score : 0.6702, acc : 0.6770, auc_score : 0.6800
# Raw Data       [ LGBMClassifier / RobustScaler & PCA(99%)               ] f1 score : 0.3342, acc : 0.5454, auc_score : 0.5191
# Processed Data [ LGBMClassifier / RobustScaler & PCA(99%)               ] f1 score : 0.6736, acc : 0.6837, auc_score : 0.6859
# Raw Data       [ LGBMClassifier / MinMaxScaler                          ] f1 score : 0.6896, acc : 0.6936, auc_score : 0.6992
# Processed Data [ LGBMClassifier / MinMaxScaler                          ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# Raw Data       [ LGBMClassifier / MinMaxScaler & PCA(90%)               ] f1 score : 0.5783, acc : 0.6400, auc_score : 0.6317
# Processed Data [ LGBMClassifier / MinMaxScaler & PCA(90%)               ] f1 score : 0.6632, acc : 0.6797, auc_score : 0.6804
# Raw Data       [ LGBMClassifier / MinMaxScaler & PCA(95%)               ] f1 score : 0.5758, acc : 0.6403, auc_score : 0.6315
# Processed Data [ LGBMClassifier / MinMaxScaler & PCA(95%)               ] f1 score : 0.6635, acc : 0.6792, auc_score : 0.6800
# Raw Data       [ LGBMClassifier / MinMaxScaler & PCA(99%)               ] f1 score : 0.5918, acc : 0.6488, auc_score : 0.6412
# Processed Data [ LGBMClassifier / MinMaxScaler & PCA(99%)               ] f1 score : 0.6838, acc : 0.6890, auc_score : 0.6925
#
#
#                               ****************************************************************
#                               ****************         XGBClassifier          ****************
#                               ****************************************************************
#
# Raw Data       [ XGBClassifier / NoScaler                               ] f1 score : 0.6611, acc : 0.6754, auc_score : 0.6779
# Processed Data [ XGBClassifier / NoScaler                               ] f1 score : 0.6716, acc : 0.6829, auc_score : 0.6848
# Raw Data       [ XGBClassifier / NoScaler & PCA(90%)                    ] f1 score : 0.3606, acc : 0.5271, auc_score : 0.5063
# Processed Data [ XGBClassifier / NoScaler & PCA(90%)                    ] f1 score : 0.6701, acc : 0.6652, auc_score : 0.6712
# Raw Data       [ XGBClassifier / NoScaler & PCA(95%)                    ] f1 score : 0.3721, acc : 0.5310, auc_score : 0.5109
# Processed Data [ XGBClassifier / NoScaler & PCA(95%)                    ] f1 score : 0.6580, acc : 0.6600, auc_score : 0.6642
# Raw Data       [ XGBClassifier / NoScaler & PCA(99%)                    ] f1 score : 0.4075, acc : 0.5323, auc_score : 0.5165
# Processed Data [ XGBClassifier / NoScaler & PCA(99%)                    ] f1 score : 0.6652, acc : 0.6757, auc_score : 0.6779
# Raw Data       [ XGBClassifier / StandardScaler                         ] f1 score : 0.6611, acc : 0.6754, auc_score : 0.6779
# Processed Data [ XGBClassifier / StandardScaler                         ] f1 score : 0.6716, acc : 0.6829, auc_score : 0.6848
# Raw Data       [ XGBClassifier / StandardScaler & PCA(90%)              ] f1 score : 0.6063, acc : 0.6498, auc_score : 0.6452
# Processed Data [ XGBClassifier / StandardScaler & PCA(90%)              ] f1 score : 0.6575, acc : 0.6751, auc_score : 0.6755
# Raw Data       [ XGBClassifier / StandardScaler & PCA(95%)              ] f1 score : 0.6054, acc : 0.6469, auc_score : 0.6428
# Processed Data [ XGBClassifier / StandardScaler & PCA(95%)              ] f1 score : 0.6519, acc : 0.6721, auc_score : 0.6719
# Raw Data       [ XGBClassifier / StandardScaler & PCA(99%)              ] f1 score : 0.6206, acc : 0.6562, auc_score : 0.6533
# Processed Data [ XGBClassifier / StandardScaler & PCA(99%)              ] f1 score : 0.6525, acc : 0.6733, auc_score : 0.6730
# Raw Data       [ XGBClassifier / RobustScaler                           ] f1 score : 0.6611, acc : 0.6754, auc_score : 0.6779
# Processed Data [ XGBClassifier / RobustScaler                           ] f1 score : 0.6717, acc : 0.6829, auc_score : 0.6849
# Raw Data       [ XGBClassifier / RobustScaler & PCA(90%)                ] f1 score : 0.3579, acc : 0.5325, auc_score : 0.5106
# Processed Data [ XGBClassifier / RobustScaler & PCA(90%)                ] f1 score : 0.6566, acc : 0.6710, auc_score : 0.6722
# Raw Data       [ XGBClassifier / RobustScaler & PCA(95%)                ] f1 score : 0.3743, acc : 0.5313, auc_score : 0.5115
# Processed Data [ XGBClassifier / RobustScaler & PCA(95%)                ] f1 score : 0.6470, acc : 0.6620, auc_score : 0.6631
# Raw Data       [ XGBClassifier / RobustScaler & PCA(99%)                ] f1 score : 0.4109, acc : 0.5395, auc_score : 0.5230
# Processed Data [ XGBClassifier / RobustScaler & PCA(99%)                ] f1 score : 0.6482, acc : 0.6674, auc_score : 0.6675
# Raw Data       [ XGBClassifier / MinMaxScaler                           ] f1 score : 0.6612, acc : 0.6755, auc_score : 0.6779
# Processed Data [ XGBClassifier / MinMaxScaler                           ] f1 score : 0.6716, acc : 0.6829, auc_score : 0.6848
# Raw Data       [ XGBClassifier / MinMaxScaler & PCA(90%)                ] f1 score : 0.5695, acc : 0.6331, auc_score : 0.6246
# Processed Data [ XGBClassifier / MinMaxScaler & PCA(90%)                ] f1 score : 0.6486, acc : 0.6722, auc_score : 0.6713
# Raw Data       [ XGBClassifier / MinMaxScaler & PCA(95%)                ] f1 score : 0.5713, acc : 0.6358, auc_score : 0.6270
# Processed Data [ XGBClassifier / MinMaxScaler & PCA(95%)                ] f1 score : 0.6508, acc : 0.6709, auc_score : 0.6708
# Raw Data       [ XGBClassifier / MinMaxScaler & PCA(99%)                ] f1 score : 0.5843, acc : 0.6407, auc_score : 0.6335
# Processed Data [ XGBClassifier / MinMaxScaler & PCA(99%)                ] f1 score : 0.6638, acc : 0.6800, auc_score : 0.6807
#
#
#                               ****************************************************************
#                               ****************         S U M M A R Y          ****************
#                               ****************************************************************
#
# [ LinearRegression             / StandardScaler / Processed Data / PCA O ] f1 score : 0.6279, acc : 0.6760, auc_score : 0.6699
# [ Ridge                        / RobustScaler   / Processed Data / PCA O ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# [ Lasso                        / NoScaler       / Raw Data       / PCA O ] f1 score : 0.4197, acc : 0.6147, auc_score : 0.5872
# [ ElasticNet                   / NoScaler       / Processed Data / PCA X ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# [ LogisticRegression           / NoScaler       / Processed Data / PCA O ] f1 score : 0.6317, acc : 0.6779, auc_score : 0.6721
# [ GaussianNB                   / RobustScaler   / Processed Data / PCA X ] f1 score : 0.6228, acc : 0.6654, auc_score : 0.6606
# [ LinearDiscriminantAnalysis   / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# [ LinearSVC                    / NoScaler       / Processed Data / PCA O ] f1 score : 0.7173, acc : 0.6826, auc_score : 0.6978
# [ DecisionTreeClassifier       / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.5740, acc : 0.6159, auc_score : 0.6120
# [ KNeighborsClassifier         / MinMaxScaler   / Processed Data / PCA X ] f1 score : 0.6239, acc : 0.6552, auc_score : 0.6528
# [ RandomForestClassifier       / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.6792, acc : 0.6924, auc_score : 0.6938
# [ AdaBoostClassifier           / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.6841, acc : 0.6929, auc_score : 0.6954
# [ GradientBoostingClassifier   / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.6908, acc : 0.6963, auc_score : 0.6997
# [ BaggingClassifier            / NoScaler       / Raw Data       / PCA O ] f1 score : 0.6021, acc : 0.6547, auc_score : 0.6479
# [ LGBMClassifier               / MinMaxScaler   / Processed Data / PCA O ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# [ XGBClassifier                / RobustScaler   / Processed Data / PCA O ] f1 score : 0.6717, acc : 0.6829, auc_score : 0.6849

# %% [markdown]
# # Result

# %%
print_max_list(max_list)
# Out:
#                               ****************************************************************
#                               ****************         S U M M A R Y          ****************
#                               ****************************************************************
#
# [ LinearRegression             / StandardScaler / Processed Data / PCA( X ) ] f1 score : 0.6279, acc : 0.6760, auc_score : 0.6699
# [ Ridge                        / RobustScaler   / Processed Data / PCA( X ) ] f1 score : 0.6259, acc : 0.6745, auc_score : 0.6683
# [ Lasso                        / NoScaler       / Raw Data       / PCA( X ) ] f1 score : 0.4197, acc : 0.6147, auc_score : 0.5872
# [ ElasticNet                   / NoScaler       / Processed Data / PCA(99%) ] f1 score : 0.5800, acc : 0.6482, auc_score : 0.6391
# [ LogisticRegression           / NoScaler       / Processed Data / PCA( X ) ] f1 score : 0.6317, acc : 0.6779, auc_score : 0.6721
# [ GaussianNB                   / RobustScaler   / Processed Data / PCA(99%) ] f1 score : 0.6228, acc : 0.6654, auc_score : 0.6606
# [ LinearDiscriminantAnalysis   / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6260, acc : 0.6744, auc_score : 0.6683
# [ LinearSVC                    / NoScaler       / Processed Data / PCA( X ) ] f1 score : 0.7173, acc : 0.6826, auc_score : 0.6978
# [ DecisionTreeClassifier       / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.5740, acc : 0.6159, auc_score : 0.6120
# [ KNeighborsClassifier         / MinMaxScaler   / Processed Data / PCA(99%) ] f1 score : 0.6239, acc : 0.6552, auc_score : 0.6528
# [ RandomForestClassifier       / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6792, acc : 0.6924, auc_score : 0.6938
# [ AdaBoostClassifier           / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6841, acc : 0.6929, auc_score : 0.6954
# [ GradientBoostingClassifier   / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6908, acc : 0.6963, auc_score : 0.6997
# [ BaggingClassifier            / NoScaler       / Raw Data       / PCA( X ) ] f1 score : 0.6021, acc : 0.6547, auc_score : 0.6479
# [ LGBMClassifier               / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6928, acc : 0.6951, auc_score : 0.6993
# [ XGBClassifier                / RobustScaler   / Processed Data / PCA( X ) ] f1 score : 0.6717, acc : 0.6829, auc_score : 0.6849

# %%
def run_model_cv(max_model_list, params):
    
    reg_check = ['Lin', 'Rid', 'Las', 'Ela']
    model, scaler, is_pca, is_edit = max_model_list[3], max_model_list[4], max_model_list[5], max_model_list[6]
    
    print(' ')
    print('*** {0} ***'.format(str(model)[:str(model).find('(')]))  
    
    if str(model)[:3] in reg_check:
        in_model = GridSearchCV(model, param_grid=params, cv=5, n_jobs = -1, verbose=1)
    else:
        in_model = GridSearchCV(model, param_grid=params, cv=5, scoring='accuracy', n_jobs = -1, verbose=1)
    
    if is_pca == 0:
        if scaler == 'NoScaler()':
            pipeline = make_pipeline(in_model)
        else:
            pipeline = make_pipeline(scaler, in_model)
    else:
        if scaler == 'NoScaler()':
            pipeline = make_pipeline(PCA(n_components=is_pca), in_model)
        else:
            pipeline = make_pipeline(scaler, PCA(n_components=is_pca), in_model)
            
    if is_edit == 0:
        x_train, y_train, x_test, y_test = x_train1, y_train1, x_test1, y_test1
    else:
        x_train, y_train, x_test, y_test = x_train2, y_train2, x_test2, y_test2
        
    pipeline.fit(x_train, y_train)
    y_pred = pipeline.predict(x_test)
    
    if str(model)[:3] in reg_check:
        y_pred = [1 if i > 0.5 else 0 for i in y_pred]
        
    f1 = f1_score(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred)

    return f1, acc, auc, model, scaler, is_pca, is_edit    


def print_max_cv_list(max_list):
    
    print(' ')
    star_print('After Grid Search')
    
    for i in max_list:
        
        if i[5] == 0:
            pca_percent = 'PCA( X )'
        else:
            if i[5] == 4:
                pca_num = 90
            elif i[5] == 5:
                pca_num = 95
            else:
                pca_num = 99        
            pca_percent = 'PCA(' + str(pca_num) + '%)'
            
        if i[6] == 0:
            is_edit = 'Raw Data'
        else:
            is_edit = 'Processed Data'
            
        print('[ {0:<28} / {1:<14} / {2:<14} / {3} ] f1 score : {4:0.04f}, acc : {5:0.04f}, auc_score : {6:0.4f}'.format(
            str(i[3])[:str(i[3]).find('(')], str(i[4])[:-2], is_edit, pca_percent, i[0], i[1], i[2]))

# %%
param_lix = ['lix', {'alpha': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 1000]}]
param_ada = ['ada', {'n_estimators':list(range(100, 600, 100)),
               'algorithm':['SAMME.R'],
               'learning_rate':[0.3, 0.5, 0.7]
             }]
param_ran = ['ran', {'n_estimators':list(range(100, 600, 100)),
               'max_depth': [2, 3, 4],
               'min_samples_split': [2, 5, 10, 100],
               'min_samples_leaf': [1, 4, 8],
             }]
param_gra = ['gra', {'n_estimators' : [100, 500],
                'max_depth' : [6, 9],
                'learning_rate' : [0.01, 0.1]
            }]
param_bag = ['bag', {'n_estimators':list(range(100, 600, 100)),
               'max_samples':[100, 200],
               'bootstrap': [True, False],
            }]
param_lgb = ['lgb', {'n_estimators':list(range(100, 600, 100)),
               'max_depth':[-1, 5, 10],
               'learning_rate': [0.1, 0.4, 0.7],
            }]
param_xgb = ['xgb', {'n_estimators':list(range(100, 600, 100)),
               'max_depth':[1, 5, 10],
               'learning_rate': [0.1, 0.4, 0.7],
            }]
param_svc = ['svc', {'C':[0.1, 0.5, 1, 5, 10]}]

param_s = [param_lix, param_ada, param_ran, param_gra, param_bag, param_lgb, param_xgb]
param_str_s = []
for param in param_s:
    param_str_s.append(param[0])
lin_s = ['rid', 'las', 'ela']

# %%
max_cv_list = []
for i in max_list:
    param_use = 'param_' + str(i[3])[:3].lower()
    
    for idx, param in enumerate(param_str_s):ㅇ
        if str(i[3])[:3].lower() in lin_s:
            max_cv_list.append(run_model_cv(i, param_s[0][1]))
            break
        elif str(i[3])[:3].lower() == param:
            max_cv_list.append(run_model_cv(i, param_s[idx][1]))
            
max_cv_list.append(run_model_cv(max_list[7], param_svc[1])) # LinearSVC

print_max_cv_list(max_cv_list)
# Out:
#
# *** Ridge ***
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    2.6s finished
#
# *** Lasso ***
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    1.9s finished
#
# *** ElasticNet ***
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.1s finished
#
# *** RandomForestClassifier ***
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:  6.0min finished
#
# *** AdaBoostClassifier ***
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:  2.6min finished
#
# *** GradientBoostingClassifier ***
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:  2.8min finished
#
# *** BaggingClassifier ***
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  5.3min finished
#
# *** LGBMClassifier ***
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:   20.5s finished
#
# *** XGBClassifier ***
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:  5.6min finished
#
# *** LinearSVC ***
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   22.8s finished
#
#                               ****************************************************************
#                               ****************       After Grid Search        ****************
#                               ****************************************************************
#
# [ Ridge                        / RobustScaler   / Processed Data / PCA( X ) ] f1 score : 0.6741, acc : 0.6254, auc_score : 0.6679
# [ Lasso                        / NoScaler       / Raw Data       / PCA( X ) ] f1 score : 0.6564, acc : 0.5963, auc_score : 0.6480
# [ ElasticNet                   / NoScaler       / Processed Data / PCA(99%) ] f1 score : 0.6561, acc : 0.6014, auc_score : 0.6491
# [ RandomForestClassifier       / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6870, acc : 0.6657, auc_score : 0.6865
# [ AdaBoostClassifier           / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6953, acc : 0.6867, auc_score : 0.6979
# [ GradientBoostingClassifier   / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6974, acc : 0.6954, auc_score : 0.7018
# [ BaggingClassifier            / NoScaler       / Raw Data       / PCA( X ) ] f1 score : 0.6778, acc : 0.6883, auc_score : 0.6879
# [ LGBMClassifier               / MinMaxScaler   / Processed Data / PCA( X ) ] f1 score : 0.6951, acc : 0.6928, auc_score : 0.6993
# [ XGBClassifier                / RobustScaler   / Processed Data / PCA( X ) ] f1 score : 0.6969, acc : 0.6934, auc_score : 0.7009
# [ LinearSVC                    / NoScaler       / Processed Data / PCA( X ) ] f1 score : 0.6868, acc : 0.6839, auc_score : 0.6909
